# %% [markdown]
# <center>
#     <img src="images/personal_logo.png"/>
# </center>

# %% [markdown]
# # Deep Unsupervised Learning - Final Project
# ### Juan Carlos Garzon Pico
# ### Viviane Alves
#
# ---
#
# <br>
#
# <div align="center">
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/Juank0621)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?logo=linkedin)](https://www.linkedin.com/in/juancarlosgarzon)
# ![Python](https://badges.aleen42.com/src/python.svg)
#
# </div>
#
# ### CIFAR10 AI System
#
# We are developing an AI system using deep learning techniques like Convolutional Autoencoders (CAE), Variational Autoencoders (VAE), and Generative Adversarial Networks (GANs) with the CIFAR10 dataset. These models will help in facial feature extraction, attribute classification, and image generation. By leveraging these approaches, we aim to enhance face recognition, noise reduction, and synthetic face generation for improved image analysis.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from PIL import Image
from tqdm import tqdm   

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CIFAR10
import torchvision.transforms.functional as TF
import torch.nn.functional as F
from torchvision.utils import save_image
from torchsummary import summary

from sklearn.metrics import roc_curve, auc

torch.set_float32_matmul_precision('medium')

# %% [markdown]
# ## PyTorch and GPU Information
#
# This code snippet displays the PyTorch version, CUDA version, cuDNN version, and the number of GPUs available for PyTorch.
#
# The first line prints the PyTorch version being used.
# The second and third lines retrieve and display the CUDA and cuDNN versions used by PyTorch.
# The final line shows the number of GPUs available for PyTorch, helping to confirm whether your system is utilizing the GPU for processing.
# This is useful for ensuring that your environment is correctly set up to use GPU acceleration.

# %%
print("PyTorch Version:", torch.__version__)
# Out:
# PyTorch Version: 2.6.0+cu124

# %%
# Get the CUDA version used by PyTorch
cuda_version = torch.version.cuda
print("CUDA Version:", cuda_version)

# Get the cuDNN version used by PyTorch
cudnn_version = torch.backends.cudnn.version()
print("cuDNN Version:", cudnn_version)
# Out:
# CUDA Version: 12.4
# cuDNN Version: 90100

# %%
# Get the number of GPUs available
num_gpus = torch.cuda.device_count()
print("Num GPUs Available:", num_gpus)
# Out:
# Num GPUs Available: 1

# %% [markdown]
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that.

# %%
# !nvidia-smi
# Out:
# Thu Apr  3 08:58:13 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080        Off | 00000000:01:00.0  On |                  N/A |
# | 30%   26C    P8              10W / 320W |    549MiB / 16376MiB |     19%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      4738      G   /usr/lib/xorg/Xorg                          156MiB |
# |    0   N/A  N/A      5485      G   /usr/bin/gnome-shell                         50MiB |
# |    0   N/A  N/A      6177      G   /usr/libexec/xdg-desktop-portal-gnome        89MiB |
# |    0   N/A  N/A     20209      G   ...eee68fbe36e507b486c2b5b1ce695adde21       28MiB |
# |    0   N/A  N/A     42636      G   ...erProcess --variations-seed-version      207MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Dataset Directory

# %% [markdown]
# Here we define the transformations to be applied to the images in the CIFAR10 dataset.

# %%
# Define transformations for the CIFAR10 dataset
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# Path to your dataset folder

# %%
dummy_dataset = CIFAR10(root='./data', train=True, download=True)
print(dummy_dataset.classes)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Custom Dataset class for loading CIFAR10 images of a specific class
class OneClassDatasetCIFAR10(CIFAR10):
    def __init__(self, root_dir, real_class=1, transform=None, train=True, download=True):
        super().__init__(root=root_dir, transform=transform, train=train, download=download)
        self.real_class = real_class
        self.samples = []
        for i in range(len(self.data)):
            if self.targets[i] == self.real_class:
                self.samples.append((self.data[i], self.targets[i]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        data = self.samples[idx]
        image = Image.fromarray(data[0])  # Convertir a objeto PIL

        # Aplicar transformaciones si están definidas
        if self.transform:
            image = self.transform(image)

        label = 0  # Dummy label as autoencoder does not need labels

        return image, label

# %%
# Load the CIFAR10 dataset
train_dataset = CIFAR10(root='data', train=True, download=True, transform=transform)
test_dataset = CIFAR10(root='data', train=False, download=True, transform=transform)

# %%
# # Create folders for saving images, one for each class
# for class_name in test_dataset.classes:
#     os.makedirs(f'./cifar10_test_images/{class_name}', exist_ok=True)

# # Save the test images to the appropriate folders
# for idx, (img, label) in enumerate(test_dataset):
#     class_name = test_dataset.classes[label]  # Get the class name for the image
#     save_image(img, f'./cifar10_test_images/{class_name}/{idx}.png')  # Save each image as PNG

# print("Test images saved in './cifar10_test_images/'")

# %%
# Split the training dataset into training and validation sets
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

# %%
classes = dummy_dataset.classes
train_class_counts = {class_name: 0 for class_name in classes}
for _, label in train_dataset:
    class_name = classes[label]
    train_class_counts[class_name] += 1

print("\nTraining set counts:")
for class_name, count in train_class_counts.items():
    print(f"Class: {class_name}, Count: {count}")
# Out:
# Training set counts:
# Class: airplane, Count: 3998
# Class: automobile, Count: 3991
# Class: bird, Count: 4000
# Class: cat, Count: 3998
# Class: deer, Count: 3986
# Class: dog, Count: 4014
# Class: frog, Count: 4042
# Class: horse, Count: 3974
# Class: ship, Count: 3965
# Class: truck, Count: 4032

# %%
val_class_counts = {class_name: 0 for class_name in classes}
for _, label in val_dataset:
    class_name = classes[label]
    val_class_counts[class_name] += 1

print("\nTraining set counts:")
for class_name, count in val_class_counts.items():
    print(f"Class: {class_name}, Count: {count}")
# Out:
# Training set counts:
# Class: airplane, Count: 1002
# Class: automobile, Count: 1009
# Class: bird, Count: 1000
# Class: cat, Count: 1002
# Class: deer, Count: 1014
# Class: dog, Count: 986
# Class: frog, Count: 958
# Class: horse, Count: 1026
# Class: ship, Count: 1035
# Class: truck, Count: 968

# %%
test_class_counts = {class_name: 0 for class_name in classes}
for _, label in test_dataset:
    class_name = classes[label]
    test_class_counts[class_name] += 1

print("\nTraining set counts:")
for class_name, count in test_class_counts.items():
    print(f"Class: {class_name}, Count: {count}")
# Out:
# Training set counts:
# Class: airplane, Count: 1000
# Class: automobile, Count: 1000
# Class: bird, Count: 1000
# Class: cat, Count: 1000
# Class: deer, Count: 1000
# Class: dog, Count: 1000
# Class: frog, Count: 1000
# Class: horse, Count: 1000
# Class: ship, Count: 1000
# Class: truck, Count: 1000

# %%
# Verify the number of images in each dataset
print(f'Number of images in training dataset: {len(train_dataset)}')
print(f'Number of images in validation dataset: {len(val_dataset)}')
print(f'Number of images in test dataset: {len(test_dataset)}')
# Out:
# Number of images in training dataset: 40000
# Number of images in validation dataset: 10000
# Number of images in test dataset: 10000

# %%
# Create data loaders for the training, validation, and test datasets
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# Function to show images from the CIFAR10 dataset
def show_transform_images(loader):
    data_iter = iter(loader)
    images, _ = next(data_iter)
    images = images.numpy()
    fig, axes = plt.subplots(2, 5, figsize=(20, 8))
    for i in range(2):
        for j in range(5):
            ax = axes[i, j]
            ax.imshow(np.transpose(images[i * 5 + j], (1, 2, 0)))
            # Set the axis labels and ticks as proportional
            ax.xaxis.set_major_locator(MaxNLocator(integer=True))
            ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    plt.show()

# %%
# Show images from the CelebA dataset
show_transform_images(train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9843137..0.99215686].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9843137..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9764706..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.90588236..0.85882354].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.9843137].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.6784314].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.96862745..0.67058825].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9529412..0.62352943].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8352941..0.92941177].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9764706..0.9529412].

# %% [markdown]
# ## Vanilla AutoEncoder

# %% [markdown]
# ### Define the Vanilla Autoencoder Model

# %%
# The latent_dim variable defines the size of the latent space.
latent_dim = 512

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.SiLU(),
            nn.MaxPool2d(2),  # 128x128 → 64x64
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.SiLU(),
            nn.MaxPool2d(2),  # 64x64 → 32x32
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.SiLU(),
            nn.MaxPool2d(2),  # 32x32 → 16x16
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.SiLU(),
            nn.MaxPool2d(2),  # 16x16 → 8x8
            
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.SiLU(),
            nn.MaxPool2d(2),  # 8x8 → 4x4
            
            nn.Flatten(),  # Flatten to a 1D vector
            nn.Linear(4 * 4 * 512, latent_dim),  # Match the output to the latent dimension
            nn.SiLU()
        )

    def forward(self, x):
        return self.encoder(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super(Decoder, self).__init__()
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 4 * 4 * 512),
            nn.SiLU(),
            nn.Unflatten(1, (512, 4, 4)),

            nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1),  # 4x4 → 8x8
            nn.BatchNorm2d(256),
            nn.SiLU(),

            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),  # 8x8 → 16x16
            nn.BatchNorm2d(128),
            nn.SiLU(),

            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),  # 16x16 → 32x32
            nn.BatchNorm2d(64),
            nn.SiLU(),

            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),  # 32x32 → 64x64
            nn.BatchNorm2d(32),
            nn.SiLU(),

            nn.ConvTranspose2d(32, 3, kernel_size=3, stride=2, padding=1, output_padding=1),  # 64x64 → 128x128
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.decoder(x)

class VanillaAutoencoder(nn.Module):
    def __init__(self, latent_dim):
        super(VanillaAutoencoder, self).__init__()
        self.encoder = Encoder(latent_dim)
        self.decoder = Decoder(latent_dim)

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
vanilla_autoencoder = VanillaAutoencoder(latent_dim)

# %%
# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
vanilla_autoencoder.to(device)
# Out:
# VanillaAutoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): SiLU()
#       (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): SiLU()
#       (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): SiLU()
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (18): SiLU()
#       (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): Flatten(start_dim=1, end_dim=-1)
#       (21): Linear(in_features=8192, out_features=512, bias=True)
#       (22): SiLU()
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=512, out_features=8192, bias=True)
#       (1): SiLU()
#       (2): Unflatten(dim=1, unflattened_size=(512, 4, 4))
#       (3): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SiLU()
#       (6): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): SiLU()
#       (9): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): SiLU()
#       (12): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (13): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): SiLU()
#       (15): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (16): Sigmoid()
#     )
#   )
# )

# %%
summary(vanilla_autoencoder, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#               SiLU-3         [-1, 32, 128, 128]               0
#          MaxPool2d-4           [-1, 32, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]          18,496
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               SiLU-7           [-1, 64, 64, 64]               0
#          MaxPool2d-8           [-1, 64, 32, 32]               0
#             Conv2d-9          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-10          [-1, 128, 32, 32]             256
#              SiLU-11          [-1, 128, 32, 32]               0
#         MaxPool2d-12          [-1, 128, 16, 16]               0
#            Conv2d-13          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              SiLU-15          [-1, 256, 16, 16]               0
#         MaxPool2d-16            [-1, 256, 8, 8]               0
#            Conv2d-17            [-1, 512, 8, 8]       1,180,160
#       BatchNorm2d-18            [-1, 512, 8, 8]           1,024
#              SiLU-19            [-1, 512, 8, 8]               0
#         MaxPool2d-20            [-1, 512, 4, 4]               0
#           Flatten-21                 [-1, 8192]               0
#            Linear-22                  [-1, 512]       4,194,816
#              SiLU-23                  [-1, 512]               0
#           Encoder-24                  [-1, 512]               0
#            Linear-25                 [-1, 8192]       4,202,496
#              SiLU-26                 [-1, 8192]               0
#         Unflatten-27            [-1, 512, 4, 4]               0
#   ConvTranspose2d-28            [-1, 256, 8, 8]       1,179,904
#       BatchNorm2d-29            [-1, 256, 8, 8]             512
#              SiLU-30            [-1, 256, 8, 8]               0
#   ConvTranspose2d-31          [-1, 128, 16, 16]         295,040
#       BatchNorm2d-32          [-1, 128, 16, 16]             256
#              SiLU-33          [-1, 128, 16, 16]               0
#   ConvTranspose2d-34           [-1, 64, 32, 32]          73,792
#       BatchNorm2d-35           [-1, 64, 32, 32]             128
#              SiLU-36           [-1, 64, 32, 32]               0
#   ConvTranspose2d-37           [-1, 32, 64, 64]          18,464
#       BatchNorm2d-38           [-1, 32, 64, 64]              64
#              SiLU-39           [-1, 32, 64, 64]               0
#   ConvTranspose2d-40          [-1, 3, 128, 128]             867
#           Sigmoid-41          [-1, 3, 128, 128]               0
#           Decoder-42          [-1, 3, 128, 128]               0
# ================================================================
# Total params: 11,536,899
# Trainable params: 11,536,899
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 32.20
# Params size (MB): 44.01
# Estimated Total Size (MB): 76.40
# ----------------------------------------------------------------

# %% [markdown]
# ### Train Vanilla Autoencoder

# %% [markdown]
# We train the vanilla autoencoder for 20 epochs.

# %%
# Function to train the model for one epoch
def train_epoch(vanilla_autoencoder, train_loader, criterion, optimizer):
    vanilla_autoencoder.train()
    total_loss = 0
    for inputs, _ in train_loader:
        inputs = inputs.to(device)
        optimizer.zero_grad()
        outputs = vanilla_autoencoder(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# Function to evaluate the model
def evaluate_model(vanilla_autoencoder, val_loader, criterion):
    vanilla_autoencoder.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, _ in val_loader:
            inputs = inputs.to(device)
            outputs = vanilla_autoencoder(inputs)
            loss = criterion(outputs, inputs)
            total_loss += loss.item()
    return total_loss / len(val_loader)

# Function to test the model and calculate AUROC
def test_model(vanilla_autoencoder, real_test_loader, ano_test_loaders):
    vanilla_autoencoder.eval()

    def get_score(loader):
        log_probs = []
        with torch.no_grad():
            for inputs, _ in loader:
                inputs = inputs.to(device)
                outputs = vanilla_autoencoder(inputs)
                mse_loss = F.mse_loss(outputs, inputs, reduction='none').mean(dim=[1, 2, 3])
                log_probs.append(mse_loss.cpu().numpy())
        return np.concatenate(log_probs)

    real_log_probs = get_score(real_test_loader)
    ano_log_probs = [get_score(loader) for loader in ano_test_loaders]
    aurocs = []
    for ano_log_prob in ano_log_probs:
        y_true = np.concatenate([np.ones_like(real_log_probs), np.zeros_like(ano_log_prob)])
        y_score = np.concatenate([real_log_probs, ano_log_prob])
        fpr, tpr, _ = roc_curve(y_true, y_score)
        roc_auc = auc(fpr, tpr)
        aurocs.append(roc_auc)

    return np.mean(aurocs)

# Function to select the threshold
def select_threshold(vanilla_autoencoder, real_test_loader, ano_test_loader):
    vanilla_autoencoder.eval()

    def get_score(loader):
        log_probs = []
        with torch.no_grad():
            for inputs, _ in loader:
                inputs = inputs.to(device)
                outputs = vanilla_autoencoder(inputs)
                mse_loss = F.mse_loss(outputs, inputs, reduction='none').mean(dim=[1, 2, 3])
                log_probs.append(mse_loss.cpu().numpy())
        return np.concatenate(log_probs)

    real_log_probs = get_score(real_test_loader)
    ano_log_probs = get_score(ano_test_loader)
    y_true = np.concatenate([np.ones_like(real_log_probs), np.zeros_like(ano_log_probs)])
    y_score = np.concatenate([real_log_probs, ano_log_probs])

    thresholds = np.linspace(0.001, 0.99, 10)
    best_threshold = 0
    best_accuracy = 0
    for threshold in thresholds:
        binary_score = y_score >= threshold
        correct = (binary_score == y_true).sum().item()
        acc = correct / len(y_true)
        if acc > best_accuracy:
            best_accuracy = acc
            best_threshold = threshold

    return best_threshold

# %%
def save_weights(model, path):
    torch.save(model.state_dict(), path)

# %%
# Main function to train and evaluate the model
def main():
    global device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Initialize confusion matrix and lists to store results
    confusion_mat = np.zeros((10, 10))
    all_aurocs = []
    all_thresholds = []
    all_train_losses = []
    all_val_losses = []

    # Loop over each class as the real class
    for real_class in range(10):
        print(f'Training for real class: {real_class}')

        # Load datasets
        train_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=True, download=True)
        val_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=False, download=True)

        train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

        real_test_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
        ano_test_loaders = [DataLoader(OneClassDatasetCIFAR10(root_dir='data', real_class=i, transform=transform, train=False, download=True), batch_size=32, shuffle=False) for i in range(10) if i != real_class]

        # Initialize model, criterion, and optimizer
        vanilla_autoencoder = VanillaAutoencoder(latent_dim).to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(vanilla_autoencoder.parameters(), lr=0.0005)

        # Training loop
        num_epochs = 30
        train_losses = []
        val_losses = []
        for epoch in range(num_epochs):
            train_loss = train_epoch(vanilla_autoencoder, train_loader, criterion, optimizer)
            val_loss = evaluate_model(vanilla_autoencoder, val_loader, criterion)
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Store losses
        all_train_losses.append(train_losses)
        all_val_losses.append(val_losses)

        # Calculate AUROC
        auroc = test_model(vanilla_autoencoder, real_test_loader, ano_test_loaders)
        all_aurocs.append(auroc)
        print(f'AUROC for class {real_class}: {auroc:.4f}')

        # Select threshold
        threshold = select_threshold(vanilla_autoencoder, real_test_loader, ano_test_loaders[0])
        all_thresholds.append(threshold)
        print(f'Selected Threshold for class {real_class}: {threshold:.4f}')

        # Update confusion matrix
        def get_predictions(loader, threshold):
            predictions = []
            with torch.no_grad():
                for inputs, _ in loader:
                    inputs = inputs.to(device)
                    outputs = vanilla_autoencoder(inputs)
                    mse_loss = F.mse_loss(outputs, inputs, reduction='none').mean(dim=[1, 2, 3])
                    preds = (mse_loss < threshold).cpu().numpy()
                    predictions.append(preds)
            return np.concatenate(predictions)

        real_preds = get_predictions(real_test_loader, threshold)
        for i, ano_loader in enumerate(ano_test_loaders):
            ano_preds = get_predictions(ano_loader, threshold)
            confusion_mat[real_class, real_class] += np.sum(real_preds == 1)
            confusion_mat[real_class, i if i < real_class else i + 1] += np.sum(ano_preds == 0)

        # Save the model weights after training for each class
        save_weights(vanilla_autoencoder, f'models/vanilla_autoencoder/vanilla_autoencoder_class_{real_class}_weights.pth')

    return confusion_mat, all_aurocs, all_thresholds, all_train_losses, all_val_losses

# %%
# Call the main function and get results
confusion_mat, all_aurocs, all_thresholds, all_train_losses, all_val_losses = main()
# Out:
# Training for real class: 0
# Epoch 1/30, Train Loss: 0.2960, Val Loss: 0.2099
# Epoch 2/30, Train Loss: 0.1897, Val Loss: 0.1528
# Epoch 3/30, Train Loss: 0.1525, Val Loss: 0.1340
# Epoch 4/30, Train Loss: 0.1356, Val Loss: 0.1204
# Epoch 5/30, Train Loss: 0.1241, Val Loss: 0.1096
# Epoch 6/30, Train Loss: 0.1166, Val Loss: 0.1029
# Epoch 7/30, Train Loss: 0.1116, Val Loss: 0.1002
# Epoch 8/30, Train Loss: 0.1091, Val Loss: 0.1016
# Epoch 9/30, Train Loss: 0.1074, Val Loss: 0.1003
# Epoch 10/30, Train Loss: 0.1054, Val Loss: 0.0947
# Epoch 11/30, Train Loss: 0.1034, Val Loss: 0.0942
# Epoch 12/30, Train Loss: 0.1021, Val Loss: 0.0928
# Epoch 13/30, Train Loss: 0.1018, Val Loss: 0.0916
# Epoch 14/30, Train Loss: 0.1003, Val Loss: 0.0926
# Epoch 15/30, Train Loss: 0.0998, Val Loss: 0.0918
# Epoch 16/30, Train Loss: 0.0986, Val Loss: 0.0912
# Epoch 17/30, Train Loss: 0.0980, Val Loss: 0.0950
# Epoch 18/30, Train Loss: 0.0991, Val Loss: 0.0912
# Epoch 19/30, Train Loss: 0.0977, Val Loss: 0.0898
# Epoch 20/30, Train Loss: 0.0971, Val Loss: 0.0896
# Epoch 21/30, Train Loss: 0.0972, Val Loss: 0.0919
# Epoch 22/30, Train Loss: 0.0979, Val Loss: 0.0907
# Epoch 23/30, Train Loss: 0.0960, Val Loss: 0.0916
# Epoch 24/30, Train Loss: 0.0957, Val Loss: 0.0882
# Epoch 25/30, Train Loss: 0.0958, Val Loss: 0.0886
# Epoch 26/30, Train Loss: 0.0952, Val Loss: 0.0899
# Epoch 27/30, Train Loss: 0.0949, Val Loss: 0.0883
# Epoch 28/30, Train Loss: 0.0939, Val Loss: 0.0882
# Epoch 29/30, Train Loss: 0.0946, Val Loss: 0.0933
# Epoch 30/30, Train Loss: 0.0954, Val Loss: 0.0874
# AUROC for class 0: 0.2692
# Selected Threshold for class 0: 0.0010
# Training for real class: 1
# Epoch 1/30, Train Loss: 0.4791, Val Loss: 0.3517
# Epoch 2/30, Train Loss: 0.3162, Val Loss: 0.2757
# Epoch 3/30, Train Loss: 0.2550, Val Loss: 0.2321
# Epoch 4/30, Train Loss: 0.2266, Val Loss: 0.2180
# Epoch 5/30, Train Loss: 0.2123, Val Loss: 0.2068
# Epoch 6/30, Train Loss: 0.2034, Val Loss: 0.2021
# Epoch 7/30, Train Loss: 0.1979, Val Loss: 0.1977
# Epoch 8/30, Train Loss: 0.1941, Val Loss: 0.1921
# Epoch 9/30, Train Loss: 0.1906, Val Loss: 0.1948
# Epoch 10/30, Train Loss: 0.1890, Val Loss: 0.1915
# Epoch 11/30, Train Loss: 0.1871, Val Loss: 0.1892
# Epoch 12/30, Train Loss: 0.1855, Val Loss: 0.1868
# Epoch 13/30, Train Loss: 0.1842, Val Loss: 0.1847
# Epoch 14/30, Train Loss: 0.1814, Val Loss: 0.1855
# Epoch 15/30, Train Loss: 0.1817, Val Loss: 0.1827
# Epoch 16/30, Train Loss: 0.1799, Val Loss: 0.1803
# Epoch 17/30, Train Loss: 0.1774, Val Loss: 0.1788
# Epoch 18/30, Train Loss: 0.1758, Val Loss: 0.1798
# Epoch 19/30, Train Loss: 0.1764, Val Loss: 0.1792
# Epoch 20/30, Train Loss: 0.1753, Val Loss: 0.1793
# Epoch 21/30, Train Loss: 0.1746, Val Loss: 0.1769
# Epoch 22/30, Train Loss: 0.1736, Val Loss: 0.1790
# Epoch 23/30, Train Loss: 0.1752, Val Loss: 0.1773
# Epoch 24/30, Train Loss: 0.1730, Val Loss: 0.1757
# Epoch 25/30, Train Loss: 0.1723, Val Loss: 0.1759
# Epoch 26/30, Train Loss: 0.1730, Val Loss: 0.1762
# Epoch 27/30, Train Loss: 0.1722, Val Loss: 0.1758
# Epoch 28/30, Train Loss: 0.1725, Val Loss: 0.1798
# Epoch 29/30, Train Loss: 0.1734, Val Loss: 0.1756
# Epoch 30/30, Train Loss: 0.1717, Val Loss: 0.1767
# AUROC for class 1: 0.6202
# Selected Threshold for class 1: 0.1109
# Training for real class: 2
# Epoch 1/30, Train Loss: 0.4090, Val Loss: 0.3082
# Epoch 2/30, Train Loss: 0.2643, Val Loss: 0.2242
# Epoch 3/30, Train Loss: 0.2062, Val Loss: 0.1853
# Epoch 4/30, Train Loss: 0.1812, Val Loss: 0.1740
# Epoch 5/30, Train Loss: 0.1679, Val Loss: 0.1632
# Epoch 6/30, Train Loss: 0.1593, Val Loss: 0.1544
# Epoch 7/30, Train Loss: 0.1532, Val Loss: 0.1516
# Epoch 8/30, Train Loss: 0.1519, Val Loss: 0.1504
# Epoch 9/30, Train Loss: 0.1489, Val Loss: 0.1828
# Epoch 10/30, Train Loss: 0.1566, Val Loss: 0.1486
# Epoch 11/30, Train Loss: 0.1461, Val Loss: 0.1472
# Epoch 12/30, Train Loss: 0.1438, Val Loss: 0.1409
# Epoch 13/30, Train Loss: 0.1415, Val Loss: 0.1408
# Epoch 14/30, Train Loss: 0.1401, Val Loss: 0.1381
# Epoch 15/30, Train Loss: 0.1375, Val Loss: 0.1373
# Epoch 16/30, Train Loss: 0.1385, Val Loss: 0.1375
# Epoch 17/30, Train Loss: 0.1377, Val Loss: 0.1376
# Epoch 18/30, Train Loss: 0.1360, Val Loss: 0.1389
# Epoch 19/30, Train Loss: 0.1358, Val Loss: 0.1352
# Epoch 20/30, Train Loss: 0.1343, Val Loss: 0.1346
# Epoch 21/30, Train Loss: 0.1351, Val Loss: 0.1457
# Epoch 22/30, Train Loss: 0.1387, Val Loss: 0.1349
# Epoch 23/30, Train Loss: 0.1344, Val Loss: 0.1345
# Epoch 24/30, Train Loss: 0.1340, Val Loss: 0.1396
# Epoch 25/30, Train Loss: 0.1379, Val Loss: 0.1357
# Epoch 26/30, Train Loss: 0.1346, Val Loss: 0.1344
# Epoch 27/30, Train Loss: 0.1331, Val Loss: 0.1336
# Epoch 28/30, Train Loss: 0.1341, Val Loss: 0.1333
# Epoch 29/30, Train Loss: 0.1327, Val Loss: 0.1332
# Epoch 30/30, Train Loss: 0.1322, Val Loss: 0.1334
# AUROC for class 2: 0.4219
# Selected Threshold for class 2: 0.1109
# Training for real class: 3
# Epoch 1/30, Train Loss: 0.4291, Val Loss: 0.3223
# Epoch 2/30, Train Loss: 0.2818, Val Loss: 0.2413
# Epoch 3/30, Train Loss: 0.2291, Val Loss: 0.2174
# Epoch 4/30, Train Loss: 0.2064, Val Loss: 0.2024
# Epoch 5/30, Train Loss: 0.1952, Val Loss: 0.1894
# Epoch 6/30, Train Loss: 0.1870, Val Loss: 0.1816
# Epoch 7/30, Train Loss: 0.1823, Val Loss: 0.1786
# Epoch 8/30, Train Loss: 0.1782, Val Loss: 0.1772
# Epoch 9/30, Train Loss: 0.1771, Val Loss: 0.1739
# Epoch 10/30, Train Loss: 0.1747, Val Loss: 0.1730
# Epoch 11/30, Train Loss: 0.1745, Val Loss: 0.1721
# Epoch 12/30, Train Loss: 0.1717, Val Loss: 0.1716
# Epoch 13/30, Train Loss: 0.1720, Val Loss: 0.1702
# Epoch 14/30, Train Loss: 0.1707, Val Loss: 0.1699
# Epoch 15/30, Train Loss: 0.1705, Val Loss: 0.1696
# Epoch 16/30, Train Loss: 0.1700, Val Loss: 0.1694
# Epoch 17/30, Train Loss: 0.1692, Val Loss: 0.1690
# Epoch 18/30, Train Loss: 0.1693, Val Loss: 0.1684
# Epoch 19/30, Train Loss: 0.1683, Val Loss: 0.1681
# Epoch 20/30, Train Loss: 0.1692, Val Loss: 0.1686
# Epoch 21/30, Train Loss: 0.1682, Val Loss: 0.1674
# Epoch 22/30, Train Loss: 0.1679, Val Loss: 0.1682
# Epoch 23/30, Train Loss: 0.1676, Val Loss: 0.1667
# Epoch 24/30, Train Loss: 0.1678, Val Loss: 0.1666
# Epoch 25/30, Train Loss: 0.1664, Val Loss: 0.1678
# Epoch 26/30, Train Loss: 0.1667, Val Loss: 0.1675
# Epoch 27/30, Train Loss: 0.1658, Val Loss: 0.1675
# Epoch 28/30, Train Loss: 0.1667, Val Loss: 0.1665
# Epoch 29/30, Train Loss: 0.1674, Val Loss: 0.1672
# Epoch 30/30, Train Loss: 0.1663, Val Loss: 0.1663
# AUROC for class 3: 0.5679
# Selected Threshold for class 3: 0.1109
# Training for real class: 4
# Epoch 1/30, Train Loss: 0.4347, Val Loss: 0.3455
# Epoch 2/30, Train Loss: 0.2864, Val Loss: 0.2365
# Epoch 3/30, Train Loss: 0.2217, Val Loss: 0.2061
# Epoch 4/30, Train Loss: 0.1922, Val Loss: 0.1860
# Epoch 5/30, Train Loss: 0.1762, Val Loss: 0.1733
# Epoch 6/30, Train Loss: 0.1661, Val Loss: 0.1657
# Epoch 7/30, Train Loss: 0.1619, Val Loss: 0.1611
# Epoch 8/30, Train Loss: 0.1563, Val Loss: 0.1562
# Epoch 9/30, Train Loss: 0.1540, Val Loss: 0.1571
# Epoch 10/30, Train Loss: 0.1514, Val Loss: 0.1529
# Epoch 11/30, Train Loss: 0.1494, Val Loss: 0.1929
# Epoch 12/30, Train Loss: 0.1637, Val Loss: 0.1579
# Epoch 13/30, Train Loss: 0.1533, Val Loss: 0.1513
# Epoch 14/30, Train Loss: 0.1481, Val Loss: 0.1498
# Epoch 15/30, Train Loss: 0.1469, Val Loss: 0.1488
# Epoch 16/30, Train Loss: 0.1455, Val Loss: 0.1471
# Epoch 17/30, Train Loss: 0.1449, Val Loss: 0.1473
# Epoch 18/30, Train Loss: 0.1440, Val Loss: 0.1489
# Epoch 19/30, Train Loss: 0.1446, Val Loss: 0.1457
# Epoch 20/30, Train Loss: 0.1430, Val Loss: 0.1450
# Epoch 21/30, Train Loss: 0.1429, Val Loss: 0.1536
# Epoch 22/30, Train Loss: 0.1513, Val Loss: 0.1473
# Epoch 23/30, Train Loss: 0.1447, Val Loss: 0.1448
# Epoch 24/30, Train Loss: 0.1445, Val Loss: 0.1448
# Epoch 25/30, Train Loss: 0.1428, Val Loss: 0.1445
# Epoch 26/30, Train Loss: 0.1418, Val Loss: 0.1437
# Epoch 27/30, Train Loss: 0.1424, Val Loss: 0.1442
# Epoch 28/30, Train Loss: 0.1426, Val Loss: 0.1452
# Epoch 29/30, Train Loss: 0.1430, Val Loss: 0.1441
# Epoch 30/30, Train Loss: 0.1417, Val Loss: 0.1435
# AUROC for class 4: 0.4746
# Selected Threshold for class 4: 0.1109
# Training for real class: 5
# Epoch 1/30, Train Loss: 0.4559, Val Loss: 0.3391
# Epoch 2/30, Train Loss: 0.2998, Val Loss: 0.2435
# Epoch 3/30, Train Loss: 0.2370, Val Loss: 0.2191
# Epoch 4/30, Train Loss: 0.2074, Val Loss: 0.1939
# Epoch 5/30, Train Loss: 0.1931, Val Loss: 0.1818
# Epoch 6/30, Train Loss: 0.1828, Val Loss: 0.1730
# Epoch 7/30, Train Loss: 0.1787, Val Loss: 0.1758
# Epoch 8/30, Train Loss: 0.1755, Val Loss: 0.1670
# Epoch 9/30, Train Loss: 0.1711, Val Loss: 0.1652
# Epoch 10/30, Train Loss: 0.1698, Val Loss: 0.1648
# Epoch 11/30, Train Loss: 0.1678, Val Loss: 0.1631
# Epoch 12/30, Train Loss: 0.1658, Val Loss: 0.1619
# Epoch 13/30, Train Loss: 0.1652, Val Loss: 0.1643
# Epoch 14/30, Train Loss: 0.1642, Val Loss: 0.1591
# Epoch 15/30, Train Loss: 0.1621, Val Loss: 0.1574
# Epoch 16/30, Train Loss: 0.1609, Val Loss: 0.1759
# Epoch 17/30, Train Loss: 0.1643, Val Loss: 0.1566
# Epoch 18/30, Train Loss: 0.1605, Val Loss: 0.1581
# Epoch 19/30, Train Loss: 0.1613, Val Loss: 0.1562
# Epoch 20/30, Train Loss: 0.1607, Val Loss: 0.1559
# Epoch 21/30, Train Loss: 0.1595, Val Loss: 0.1548
# Epoch 22/30, Train Loss: 0.1584, Val Loss: 0.1545
# Epoch 23/30, Train Loss: 0.1575, Val Loss: 0.1539
# Epoch 24/30, Train Loss: 0.1573, Val Loss: 0.1538
# Epoch 25/30, Train Loss: 0.1568, Val Loss: 0.1549
# Epoch 26/30, Train Loss: 0.1573, Val Loss: 0.1544
# Epoch 27/30, Train Loss: 0.1574, Val Loss: 0.1643
# Epoch 28/30, Train Loss: 0.1619, Val Loss: 0.1548
# Epoch 29/30, Train Loss: 0.1573, Val Loss: 0.1538
# Epoch 30/30, Train Loss: 0.1569, Val Loss: 0.1533
# AUROC for class 5: 0.5369
# Selected Threshold for class 5: 0.1109
# Training for real class: 6
# Epoch 1/30, Train Loss: 0.4826, Val Loss: 0.3714
# Epoch 2/30, Train Loss: 0.3316, Val Loss: 0.2863
# Epoch 3/30, Train Loss: 0.2616, Val Loss: 0.2310
# Epoch 4/30, Train Loss: 0.2279, Val Loss: 0.2099
# Epoch 5/30, Train Loss: 0.2097, Val Loss: 0.2023
# Epoch 6/30, Train Loss: 0.1996, Val Loss: 0.1929
# Epoch 7/30, Train Loss: 0.1934, Val Loss: 0.1904
# Epoch 8/30, Train Loss: 0.1878, Val Loss: 0.1842
# Epoch 9/30, Train Loss: 0.1864, Val Loss: 0.1829
# Epoch 10/30, Train Loss: 0.1829, Val Loss: 0.1834
# Epoch 11/30, Train Loss: 0.1819, Val Loss: 0.1777
# Epoch 12/30, Train Loss: 0.1798, Val Loss: 0.1773
# Epoch 13/30, Train Loss: 0.1781, Val Loss: 0.1770
# Epoch 14/30, Train Loss: 0.1777, Val Loss: 0.2009
# Epoch 15/30, Train Loss: 0.1906, Val Loss: 0.1807
# Epoch 16/30, Train Loss: 0.1809, Val Loss: 0.1776
# Epoch 17/30, Train Loss: 0.1795, Val Loss: 0.1761
# Epoch 18/30, Train Loss: 0.1782, Val Loss: 0.1753
# Epoch 19/30, Train Loss: 0.1751, Val Loss: 0.1730
# Epoch 20/30, Train Loss: 0.1748, Val Loss: 0.1729
# Epoch 21/30, Train Loss: 0.1735, Val Loss: 0.1717
# Epoch 22/30, Train Loss: 0.1735, Val Loss: 0.1714
# Epoch 23/30, Train Loss: 0.1738, Val Loss: 0.1714
# Epoch 24/30, Train Loss: 0.1737, Val Loss: 0.1717
# Epoch 25/30, Train Loss: 0.1728, Val Loss: 0.1837
# Epoch 26/30, Train Loss: 0.1792, Val Loss: 0.1732
# Epoch 27/30, Train Loss: 0.1738, Val Loss: 0.1717
# Epoch 28/30, Train Loss: 0.1734, Val Loss: 0.1707
# Epoch 29/30, Train Loss: 0.1716, Val Loss: 0.1713
# Epoch 30/30, Train Loss: 0.1722, Val Loss: 0.1700
# AUROC for class 6: 0.5530
# Selected Threshold for class 6: 0.1109
# Training for real class: 7
# Epoch 1/30, Train Loss: 0.4477, Val Loss: 0.3288
# Epoch 2/30, Train Loss: 0.2857, Val Loss: 0.2411
# Epoch 3/30, Train Loss: 0.2235, Val Loss: 0.2042
# Epoch 4/30, Train Loss: 0.1949, Val Loss: 0.1875
# Epoch 5/30, Train Loss: 0.1809, Val Loss: 0.1735
# Epoch 6/30, Train Loss: 0.1716, Val Loss: 0.1662
# Epoch 7/30, Train Loss: 0.1672, Val Loss: 0.1632
# Epoch 8/30, Train Loss: 0.1620, Val Loss: 0.1602
# Epoch 9/30, Train Loss: 0.1587, Val Loss: 0.1542
# Epoch 10/30, Train Loss: 0.1568, Val Loss: 0.1545
# Epoch 11/30, Train Loss: 0.1547, Val Loss: 0.1521
# Epoch 12/30, Train Loss: 0.1527, Val Loss: 0.1507
# Epoch 13/30, Train Loss: 0.1524, Val Loss: 0.1497
# Epoch 14/30, Train Loss: 0.1508, Val Loss: 0.1491
# Epoch 15/30, Train Loss: 0.1499, Val Loss: 0.1475
# Epoch 16/30, Train Loss: 0.1495, Val Loss: 0.1471
# Epoch 17/30, Train Loss: 0.1491, Val Loss: 0.1480
# Epoch 18/30, Train Loss: 0.1479, Val Loss: 0.1483
# Epoch 19/30, Train Loss: 0.1473, Val Loss: 0.1461
# Epoch 20/30, Train Loss: 0.1480, Val Loss: 0.1457
# Epoch 21/30, Train Loss: 0.1465, Val Loss: 0.1452
# Epoch 22/30, Train Loss: 0.1462, Val Loss: 0.1466
# Epoch 23/30, Train Loss: 0.1467, Val Loss: 0.1454
# Epoch 24/30, Train Loss: 0.1449, Val Loss: 0.1447
# Epoch 25/30, Train Loss: 0.1441, Val Loss: 0.1440
# Epoch 26/30, Train Loss: 0.1443, Val Loss: 0.1448
# Epoch 27/30, Train Loss: 0.1441, Val Loss: 0.1447
# Epoch 28/30, Train Loss: 0.1444, Val Loss: 0.1437
# Epoch 29/30, Train Loss: 0.1435, Val Loss: 0.1442
# Epoch 30/30, Train Loss: 0.1434, Val Loss: 0.1448
# AUROC for class 7: 0.5248
# Selected Threshold for class 7: 0.1109
# Training for real class: 8
# Epoch 1/30, Train Loss: 0.2891, Val Loss: 0.2127
# Epoch 2/30, Train Loss: 0.1832, Val Loss: 0.1668
# Epoch 3/30, Train Loss: 0.1491, Val Loss: 0.1363
# Epoch 4/30, Train Loss: 0.1344, Val Loss: 0.1289
# Epoch 5/30, Train Loss: 0.1273, Val Loss: 0.1240
# Epoch 6/30, Train Loss: 0.1219, Val Loss: 0.1207
# Epoch 7/30, Train Loss: 0.1190, Val Loss: 0.1165
# Epoch 8/30, Train Loss: 0.1162, Val Loss: 0.1158
# Epoch 9/30, Train Loss: 0.1158, Val Loss: 0.1146
# Epoch 10/30, Train Loss: 0.1143, Val Loss: 0.1142
# Epoch 11/30, Train Loss: 0.1135, Val Loss: 0.1144
# Epoch 12/30, Train Loss: 0.1128, Val Loss: 0.1135
# Epoch 13/30, Train Loss: 0.1127, Val Loss: 0.1146
# Epoch 14/30, Train Loss: 0.1115, Val Loss: 0.1115
# Epoch 15/30, Train Loss: 0.1109, Val Loss: 0.1113
# Epoch 16/30, Train Loss: 0.1101, Val Loss: 0.1098
# Epoch 17/30, Train Loss: 0.1101, Val Loss: 0.1100
# Epoch 18/30, Train Loss: 0.1093, Val Loss: 0.1101
# Epoch 19/30, Train Loss: 0.1099, Val Loss: 0.1116
# Epoch 20/30, Train Loss: 0.1092, Val Loss: 0.1102
# Epoch 21/30, Train Loss: 0.1089, Val Loss: 0.1106
# Epoch 22/30, Train Loss: 0.1087, Val Loss: 0.1106
# Epoch 23/30, Train Loss: 0.1089, Val Loss: 0.1094
# Epoch 24/30, Train Loss: 0.1082, Val Loss: 0.1098
# Epoch 25/30, Train Loss: 0.1080, Val Loss: 0.1095
# Epoch 26/30, Train Loss: 0.1077, Val Loss: 0.1097
# Epoch 27/30, Train Loss: 0.1074, Val Loss: 0.1096
# Epoch 28/30, Train Loss: 0.1070, Val Loss: 0.1088
# Epoch 29/30, Train Loss: 0.1067, Val Loss: 0.1087
# Epoch 30/30, Train Loss: 0.1066, Val Loss: 0.1090
# AUROC for class 8: 0.3767
# Selected Threshold for class 8: 0.1109
# Training for real class: 9
# Epoch 1/30, Train Loss: 0.4386, Val Loss: 0.3440
# Epoch 2/30, Train Loss: 0.2714, Val Loss: 0.2445
# Epoch 3/30, Train Loss: 0.2140, Val Loss: 0.1944
# Epoch 4/30, Train Loss: 0.1900, Val Loss: 0.1770
# Epoch 5/30, Train Loss: 0.1779, Val Loss: 0.1698
# Epoch 6/30, Train Loss: 0.1706, Val Loss: 0.1623
# Epoch 7/30, Train Loss: 0.1660, Val Loss: 0.1586
# Epoch 8/30, Train Loss: 0.1630, Val Loss: 0.1564
# Epoch 9/30, Train Loss: 0.1591, Val Loss: 0.1531
# Epoch 10/30, Train Loss: 0.1568, Val Loss: 0.1543
# Epoch 11/30, Train Loss: 0.1562, Val Loss: 0.1518
# Epoch 12/30, Train Loss: 0.1550, Val Loss: 0.1498
# Epoch 13/30, Train Loss: 0.1535, Val Loss: 0.1500
# Epoch 14/30, Train Loss: 0.1530, Val Loss: 0.1494
# Epoch 15/30, Train Loss: 0.1515, Val Loss: 0.1475
# Epoch 16/30, Train Loss: 0.1513, Val Loss: 0.1484
# Epoch 17/30, Train Loss: 0.1506, Val Loss: 0.1467
# Epoch 18/30, Train Loss: 0.1500, Val Loss: 0.1473
# Epoch 19/30, Train Loss: 0.1501, Val Loss: 0.1480
# Epoch 20/30, Train Loss: 0.1502, Val Loss: 0.1479
# Epoch 21/30, Train Loss: 0.1492, Val Loss: 0.1466
# Epoch 22/30, Train Loss: 0.1483, Val Loss: 0.1458
# Epoch 23/30, Train Loss: 0.1480, Val Loss: 0.1454
# Epoch 24/30, Train Loss: 0.1472, Val Loss: 0.1452
# Epoch 25/30, Train Loss: 0.1473, Val Loss: 0.1456
# Epoch 26/30, Train Loss: 0.1473, Val Loss: 0.1457
# Epoch 27/30, Train Loss: 0.1471, Val Loss: 0.1458
# Epoch 28/30, Train Loss: 0.1469, Val Loss: 0.1459
# Epoch 29/30, Train Loss: 0.1462, Val Loss: 0.1451
# Epoch 30/30, Train Loss: 0.1458, Val Loss: 0.1448
# AUROC for class 9: 0.5525
# Selected Threshold for class 9: 0.1109

# %%
# Función para graficar las pérdidas
def plot_losses(train_losses, val_losses, class_index):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss for Class {class_index}')
    plt.legend()
    plt.show()

# Función para graficar la matriz de confusión
def plot_confusion_matrix(confusion_mat):
    plt.figure(figsize=(10, 7))
    sns.heatmap(confusion_mat, annot=True, fmt='g', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Función para graficar AUROC y umbrales
def plot_auroc_thresholds(aurocs, thresholds):
    plt.figure(figsize=(10, 5))
    plt.bar(range(10), aurocs, alpha=0.6, label='AUROC')
    plt.plot(range(10), thresholds, marker='o', linestyle='--', color='red', label='Threshold')
    plt.xlabel('Class')
    plt.ylabel('Value')
    plt.title('AUROC and Thresholds for Each Class')
    plt.legend()
    plt.show()

# %%
# Plot confusion matrix
plot_confusion_matrix(confusion_mat)

# Plot AUROC and thresholds
plot_auroc_thresholds(all_aurocs, all_thresholds)

# Plot losses for each class
for real_class in range(10):
    plot_losses(all_train_losses[real_class], all_val_losses[real_class], real_class)

# %%
def load_weights(model, path):
    model.load_state_dict(torch.load(path)) # Load the saved model weights
    model.eval()  # Important: Set the model to evaluation mode

# %%
# Function to display 5 original and reconstructed images from the test dataset
from torch.utils.data import Subset

def compare_images(test_loader):
    images, reconstructed_images = [], []
    for class_index in range(10):

        class_indices = [i for i, (_, label) in enumerate(test_dataset) if label == class_index]
        class_subset = Subset(test_dataset, class_indices)
        class_loader = DataLoader(class_subset, batch_size=1, shuffle=False) 
    
        # Load the model for the specific class
        vanilla_autoencoder = VanillaAutoencoder(latent_dim).to(device)
        load_weights(vanilla_autoencoder, f'models/vanilla_autoencoder/vanilla_autoencoder_class_{class_index}_weights.pth')
        vanilla_autoencoder.eval()
        
        with torch.no_grad():
            # for i, (inputs, _) in enumerate(test_loader):
            #    if i >= 1:
            #        break
            inputs, _ = next(iter(class_loader))
            inputs = inputs.to(device)
            outputs = vanilla_autoencoder(inputs)
            images.append(inputs[0].cpu())  # toma solo la primera imagen del batch
            reconstructed_images.append(outputs[0].cpu())  # toma solo la primera imagen reconstruida
            # break  # solo quieres una imagen por clase

    fig, axs = plt.subplots(10, 2, figsize=(10, 20))
    for i in range(10):
        axs[i, 0].imshow(images[i].permute(1, 2, 0).numpy())
        axs[i, 0].set_title("Original")
        axs[i, 0].axis("off")
        axs[i, 1].imshow(reconstructed_images[i].permute(1, 2, 0).numpy())
        axs[i, 1].set_title(f"Reconstructed (Class {i})")
        axs[i, 1].axis("off")
    plt.show()

# %%
# Display 5 original and reconstructed images from the test dataset using different models for each class
compare_images(test_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7019608..0.827451].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.9764706].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9137255..0.92941177].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8745098..0.9843137].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.827451..0.56078434].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9607843..0.6156863].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.92941177..0.7019608].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.99215686].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.92156863].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.90588236..1.0].

# %% [markdown]
# ## Denoising AutoEncoder

# %% [markdown]
# ### Function to add noise to images

# %% [markdown]
# This function adds Gaussian noise to the input images.

# %%
# Function to add noise to images
def add_noise(img):
    noise = torch.randn_like(img) * 0.1
    img_noisy = torch.clamp(img + noise, 0., 1.)
    return img_noisy

# Function to train the denoising autoencoder for one epoch
def train_denoising_epoch(denoising_autoencoder, train_loader, criterion, optimizer):
    denoising_autoencoder.train()
    total_loss = 0
    for inputs, _ in train_loader:
        inputs = inputs.to(device)
        inputs_noisy = add_noise(inputs)
        optimizer.zero_grad()
        outputs = denoising_autoencoder(inputs_noisy)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# %% [markdown]
# ### Train Denoising Autoencoder

# %% [markdown]
# We train the denoising autoencoder for 20 epochs.

# %%
# Main function to train and evaluate the denoising autoencoder model
def main_denoising():
    global device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Initialize confusion matrix and lists to store results
    confusion_mat = np.zeros((10, 10))
    all_aurocs = []
    all_thresholds = []
    all_train_losses = []
    all_val_losses = []

    # Loop over each class as the real class
    for real_class in range(10):
        print(f'Training for real class: {real_class}')

        # Load datasets
        train_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=True, download=True)
        val_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=False, download=True)

        train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

        real_test_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)
        ano_test_loaders = [DataLoader(OneClassDatasetCIFAR10(root_dir='data', real_class=i, transform=transform, train=False, download=True), batch_size=32, shuffle=False) for i in range(10) if i != real_class]

        # Initialize model, criterion, and optimizer
        denoising_autoencoder = VanillaAutoencoder(latent_dim).to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(denoising_autoencoder.parameters(), lr=0.0005)

        # Training loop
        num_epochs = 10
        train_losses = []
        val_losses = []
        for epoch in range(num_epochs):
            train_loss = train_denoising_epoch(denoising_autoencoder, train_loader, criterion, optimizer)
            val_loss = evaluate_model(denoising_autoencoder, val_loader, criterion)
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Store losses
        all_train_losses.append(train_losses)
        all_val_losses.append(val_losses)

        # Calculate AUROC
        auroc = test_model(denoising_autoencoder, real_test_loader, ano_test_loaders)
        all_aurocs.append(auroc)
        print(f'AUROC for class {real_class}: {auroc:.4f}')

        # Select threshold
        threshold = select_threshold(denoising_autoencoder, real_test_loader, ano_test_loaders[0])
        all_thresholds.append(threshold)
        print(f'Selected Threshold for class {real_class}: {threshold:.4f}')

        # Update confusion matrix
        def get_predictions(loader, threshold):
            predictions = []
            with torch.no_grad():
                for inputs, _ in loader:
                    inputs = inputs.to(device)
                    outputs = denoising_autoencoder(inputs)
                    mse_loss = F.mse_loss(outputs, inputs, reduction='none').mean(dim=[1, 2, 3])
                    preds = (mse_loss < threshold).cpu().numpy()
                    predictions.append(preds)
            return np.concatenate(predictions)

        real_preds = get_predictions(real_test_loader, threshold)
        for i, ano_loader in enumerate(ano_test_loaders):
            ano_preds = get_predictions(ano_loader, threshold)
            confusion_mat[real_class, real_class] += np.sum(real_preds == 1)
            confusion_mat[real_class, i if i < real_class else i + 1] += np.sum(ano_preds == 0)

        # Save the model weights after training for each class
        save_weights(denoising_autoencoder, f'models/denoising_autoencoder/denoising_autoencoder_class_{real_class}_weights.pth')

    return confusion_mat, all_aurocs, all_thresholds, all_train_losses, all_val_losses

# %%
# Call the main function for denoising autoencoder and get results
confusion_mat, all_aurocs, all_thresholds, all_train_losses, all_val_losses = main_denoising()
# Out:
# Training for real class: 0
# Epoch 1/10, Train Loss: 0.3099, Val Loss: 0.2192
# Epoch 2/10, Train Loss: 0.2143, Val Loss: 0.1900
# Epoch 3/10, Train Loss: 0.1770, Val Loss: 0.1802
# Epoch 4/10, Train Loss: 0.1571, Val Loss: 0.1715
# Epoch 5/10, Train Loss: 0.1421, Val Loss: 0.1522
# Epoch 6/10, Train Loss: 0.1297, Val Loss: 0.1455
# Epoch 7/10, Train Loss: 0.1216, Val Loss: 0.1464
# Epoch 8/10, Train Loss: 0.1155, Val Loss: 0.1379
# Epoch 9/10, Train Loss: 0.1130, Val Loss: 0.1438
# Epoch 10/10, Train Loss: 0.1086, Val Loss: 0.1337
# AUROC for class 0: 0.2991
# Selected Threshold for class 0: 0.8801
# Training for real class: 1
# Epoch 1/10, Train Loss: 0.5435, Val Loss: 0.4715
# Epoch 2/10, Train Loss: 0.4050, Val Loss: 0.3551
# Epoch 3/10, Train Loss: 0.3329, Val Loss: 0.2924
# Epoch 4/10, Train Loss: 0.2835, Val Loss: 0.2538
# Epoch 5/10, Train Loss: 0.2553, Val Loss: 0.2448
# Epoch 6/10, Train Loss: 0.2352, Val Loss: 0.2342
# Epoch 7/10, Train Loss: 0.2235, Val Loss: 0.2319
# Epoch 8/10, Train Loss: 0.2135, Val Loss: 0.2336
# Epoch 9/10, Train Loss: 0.2073, Val Loss: 0.2256
# Epoch 10/10, Train Loss: 0.2035, Val Loss: 0.2288
# AUROC for class 1: 0.6297
# Selected Threshold for class 1: 0.2208
# Training for real class: 2
# Epoch 1/10, Train Loss: 0.4480, Val Loss: 0.3000
# Epoch 2/10, Train Loss: 0.3398, Val Loss: 0.2987
# Epoch 3/10, Train Loss: 0.2774, Val Loss: 0.2683
# Epoch 4/10, Train Loss: 0.2377, Val Loss: 0.2551
# Epoch 5/10, Train Loss: 0.2136, Val Loss: 0.2400
# Epoch 6/10, Train Loss: 0.1945, Val Loss: 0.1993
# Epoch 7/10, Train Loss: 0.1868, Val Loss: 0.1840
# Epoch 8/10, Train Loss: 0.1768, Val Loss: 0.1849
# Epoch 9/10, Train Loss: 0.1678, Val Loss: 0.1762
# Epoch 10/10, Train Loss: 0.1632, Val Loss: 0.1810
# AUROC for class 2: 0.4130
# Selected Threshold for class 2: 0.2208
# Training for real class: 3
# Epoch 1/10, Train Loss: 0.5040, Val Loss: 0.4028
# Epoch 2/10, Train Loss: 0.3762, Val Loss: 0.3420
# Epoch 3/10, Train Loss: 0.3118, Val Loss: 0.2857
# Epoch 4/10, Train Loss: 0.2697, Val Loss: 0.2633
# Epoch 5/10, Train Loss: 0.2425, Val Loss: 0.2516
# Epoch 6/10, Train Loss: 0.2264, Val Loss: 0.2362
# Epoch 7/10, Train Loss: 0.2130, Val Loss: 0.2350
# Epoch 8/10, Train Loss: 0.2030, Val Loss: 0.2289
# Epoch 9/10, Train Loss: 0.1968, Val Loss: 0.2316
# Epoch 10/10, Train Loss: 0.1943, Val Loss: 0.2301
# AUROC for class 3: 0.5693
# Selected Threshold for class 3: 0.2208
# Training for real class: 4
# Epoch 1/10, Train Loss: 0.4931, Val Loss: 0.4853
# Epoch 2/10, Train Loss: 0.3788, Val Loss: 0.3215
# Epoch 3/10, Train Loss: 0.3076, Val Loss: 0.2770
# Epoch 4/10, Train Loss: 0.2613, Val Loss: 0.2370
# Epoch 5/10, Train Loss: 0.2304, Val Loss: 0.2270
# Epoch 6/10, Train Loss: 0.2081, Val Loss: 0.2376
# Epoch 7/10, Train Loss: 0.1947, Val Loss: 0.2936
# Epoch 8/10, Train Loss: 0.1843, Val Loss: 0.5944
# Epoch 9/10, Train Loss: 0.1878, Val Loss: 0.2898
# Epoch 10/10, Train Loss: 0.1731, Val Loss: 0.2119
# AUROC for class 4: 0.4645
# Selected Threshold for class 4: 0.2208
# Training for real class: 5
# Epoch 1/10, Train Loss: 0.5123, Val Loss: 0.4514
# Epoch 2/10, Train Loss: 0.3948, Val Loss: 0.3359
# Epoch 3/10, Train Loss: 0.3229, Val Loss: 0.2802
# Epoch 4/10, Train Loss: 0.2830, Val Loss: 0.2825
# Epoch 5/10, Train Loss: 0.2547, Val Loss: 0.2418
# Epoch 6/10, Train Loss: 0.2319, Val Loss: 0.2310
# Epoch 7/10, Train Loss: 0.2164, Val Loss: 0.2223
# Epoch 8/10, Train Loss: 0.2068, Val Loss: 0.2205
# Epoch 9/10, Train Loss: 0.1998, Val Loss: 0.2258
# Epoch 10/10, Train Loss: 0.1929, Val Loss: 0.2129
# AUROC for class 5: 0.5452
# Selected Threshold for class 5: 0.2208
# Training for real class: 6
# Epoch 1/10, Train Loss: 0.5143, Val Loss: 0.5464
# Epoch 2/10, Train Loss: 0.4108, Val Loss: 0.5232
# Epoch 3/10, Train Loss: 0.3391, Val Loss: 0.4034
# Epoch 4/10, Train Loss: 0.2905, Val Loss: 0.3212
# Epoch 5/10, Train Loss: 0.2638, Val Loss: 0.2911
# Epoch 6/10, Train Loss: 0.2417, Val Loss: 0.3682
# Epoch 7/10, Train Loss: 0.2230, Val Loss: 0.3351
# Epoch 8/10, Train Loss: 0.2115, Val Loss: 0.4878
# Epoch 9/10, Train Loss: 0.2048, Val Loss: 0.4341
# Epoch 10/10, Train Loss: 0.1982, Val Loss: 0.5863
# AUROC for class 6: 0.5265
# Selected Threshold for class 6: 0.4406
# Training for real class: 7
# Epoch 1/10, Train Loss: 0.4656, Val Loss: 0.3253
# Epoch 2/10, Train Loss: 0.3501, Val Loss: 0.2924
# Epoch 3/10, Train Loss: 0.2921, Val Loss: 0.2647
# Epoch 4/10, Train Loss: 0.2513, Val Loss: 0.2391
# Epoch 5/10, Train Loss: 0.2250, Val Loss: 0.2248
# Epoch 6/10, Train Loss: 0.2078, Val Loss: 0.2021
# Epoch 7/10, Train Loss: 0.1981, Val Loss: 0.2131
# Epoch 8/10, Train Loss: 0.1868, Val Loss: 0.2052
# Epoch 9/10, Train Loss: 0.1810, Val Loss: 0.1973
# Epoch 10/10, Train Loss: 0.1780, Val Loss: 0.2020
# AUROC for class 7: 0.5177
# Selected Threshold for class 7: 0.1109
# Training for real class: 8
# Epoch 1/10, Train Loss: 0.3535, Val Loss: 0.2395
# Epoch 2/10, Train Loss: 0.2530, Val Loss: 0.2185
# Epoch 3/10, Train Loss: 0.2045, Val Loss: 0.1967
# Epoch 4/10, Train Loss: 0.1756, Val Loss: 0.1780
# Epoch 5/10, Train Loss: 0.1598, Val Loss: 0.1685
# Epoch 6/10, Train Loss: 0.1513, Val Loss: 0.1673
# Epoch 7/10, Train Loss: 0.1405, Val Loss: 0.1529
# Epoch 8/10, Train Loss: 0.1359, Val Loss: 0.1466
# Epoch 9/10, Train Loss: 0.1305, Val Loss: 0.1531
# Epoch 10/10, Train Loss: 0.1319, Val Loss: 0.1441
# AUROC for class 8: 0.3882
# Selected Threshold for class 8: 0.1109
# Training for real class: 9
# Epoch 1/10, Train Loss: 0.4574, Val Loss: 0.3410
# Epoch 2/10, Train Loss: 0.3444, Val Loss: 0.2824
# Epoch 3/10, Train Loss: 0.2780, Val Loss: 0.2437
# Epoch 4/10, Train Loss: 0.2429, Val Loss: 0.2216
# Epoch 5/10, Train Loss: 0.2189, Val Loss: 0.2183
# Epoch 6/10, Train Loss: 0.2031, Val Loss: 0.2127
# Epoch 7/10, Train Loss: 0.1943, Val Loss: 0.2199
# Epoch 8/10, Train Loss: 0.1860, Val Loss: 0.2058
# Epoch 9/10, Train Loss: 0.1801, Val Loss: 0.2059
# Epoch 10/10, Train Loss: 0.1774, Val Loss: 0.2010
# AUROC for class 9: 0.5786
# Selected Threshold for class 9: 0.1109

# %%
# Plot confusion matrix
plot_confusion_matrix(confusion_mat)

# Plot AUROC and thresholds
plot_auroc_thresholds(all_aurocs, all_thresholds)

# Plot losses for each class
for real_class in range(10):
    plot_losses(all_train_losses[real_class], all_val_losses[real_class], real_class)

# %%
def load_weights(model, path):
    model.load_state_dict(torch.load(path)) # Load the saved model weights
    model.eval()  # Important: Set the model to evaluation mode

# %% [markdown]
# ## Variational autoencoder (VAE)

# %%
class VAEEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(VAEEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )
        self.mean = nn.Linear(hidden_dim, latent_dim)
        self.log_var = nn.Linear(hidden_dim, latent_dim)

    def forward(self, x):
        h = self.encoder(x)
        mean = self.mean(h)
        log_var = self.log_var(h)
        return mean, log_var

# %%
class VAEDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_dim):
        super(VAEDecoder, self).__init__()
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
            nn.Sigmoid()
        )

    def forward(self, z):
        return self.decoder(z)

# %%
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(VAE, self).__init__()
        self.encoder = VAEEncoder(input_dim, hidden_dim, latent_dim)
        self.decoder = VAEDecoder(latent_dim, hidden_dim, input_dim)

    def reparameterize(self, mean, log_var):
        std = torch.exp(0.5 * log_var)
        epsilon = torch.randn_like(std)
        return mean + epsilon * std

    def forward(self, x):
        mean, log_var = self.encoder(x)
        z = self.reparameterize(mean, log_var)
        x_hat = self.decoder(z)
        return x_hat, mean, log_var

# %%
def vae_loss_function(x, x_hat, mean, log_var):
    reconstruction_loss = nn.functional.mse_loss(x_hat, x, reduction='sum')
    kl_divergence = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
    return reconstruction_loss + kl_divergence


def train_vae_epoch(vae, train_loader, optimizer):
    vae.train()
    total_loss = 0
    for inputs, _ in train_loader:
        inputs = inputs.view(inputs.size(0), -1).to(device)
        optimizer.zero_grad()
        x_hat, mean, log_var = vae(inputs)
        loss = vae_loss_function(inputs, x_hat, mean, log_var)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)


def evaluate_vae(vae, val_loader):
    vae.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, _ in val_loader:
            inputs = inputs.view(inputs.size(0), -1).to(device)
            x_hat, mean, log_var = vae(inputs)
            loss = vae_loss_function(inputs, x_hat, mean, log_var)
            total_loss += loss.item()
    return total_loss / len(val_loader)


def calculate_mahalanobis_distance(mean, covariance, x):
    diff = x - mean
    inv_covariance = torch.linalg.inv(covariance)
    distance = torch.sqrt(torch.mm(torch.mm(diff.unsqueeze(0), inv_covariance), diff.unsqueeze(1)))
    return distance.item()


def test_vae(vae, test_loader, threshold):
    vae.eval()
    anomalies = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.view(inputs.size(0), -1).to(device)
            x_hat, mean, log_var = vae(inputs)
            z = vae.reparameterize(mean, log_var)
            distances = [calculate_mahalanobis_distance(mean[i], torch.eye(mean.size(1)).to(device), z[i]) for i in range(z.size(0))]
            anomalies.extend([d > threshold for d in distances])
    return anomalies

# %%
def main_vae():
    input_dim = 128 * 128 * 3
    hidden_dim = 512
    latent_dim = 128
    num_epochs = 10
    learning_rate = 0.001

    vae = VAE(input_dim, hidden_dim, latent_dim).to(device)
    optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)

    all_train_losses = []
    all_val_losses = []

    for real_class in range(10):
        print(f"Training VAE for class {real_class}...")

        train_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=True, download=True)
        val_dataset = OneClassDatasetCIFAR10(root_dir='data', real_class=real_class, transform=transform, train=False, download=True)

        train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

        train_losses = []
        val_losses = []

        for epoch in range(num_epochs):
            train_loss = train_vae_epoch(vae, train_loader, optimizer)
            val_loss = evaluate_vae(vae, val_loader)
            train_losses.append(train_loss)
            val_losses.append(val_loss)
            print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        all_train_losses.append(train_losses)
        all_val_losses.append(val_losses)

        # Save the trained model
        torch.save(vae.state_dict(), f'models/vae/vae_class_{real_class}_weights.pth')

    return all_train_losses, all_val_losses

# %%
# Call the main function for VAE
all_train_losses, all_val_losses = main_vae()
# Out:
# Training VAE for class 0...
# Epoch 1/10, Train Loss: 2747215063.2306, Val Loss: 1203175.7031
# Epoch 2/10, Train Loss: 51014075203438016.0000, Val Loss: 1393824.4375
# Epoch 3/10, Train Loss: 1321606.5260, Val Loss: 1322614.8789
# Epoch 4/10, Train Loss: 7088525053240755143835648.0000, Val Loss: 1809859.8516
# Epoch 5/10, Train Loss: 1238560.4035, Val Loss: 2966761.3516
# Epoch 6/10, Train Loss: 1392725.4648, Val Loss: 459631981.1484
# Epoch 7/10, Train Loss: 1631496.3212, Val Loss: 1336660.7188
# Epoch 8/10, Train Loss: 79636866.0079, Val Loss: 1756761.2852
# Epoch 9/10, Train Loss: 7894779.6602, Val Loss: 1500814.8516
# Epoch 10/10, Train Loss: 28851033474581369259087101952.0000, Val Loss: 3260102615076905974931832180985298944.0000
# Training VAE for class 1...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 2...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 3...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 4...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 5...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 6...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 7...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 8...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan
# Training VAE for class 9...
# Epoch 1/10, Train Loss: nan, Val Loss: nan
# Epoch 2/10, Train Loss: nan, Val Loss: nan
# Epoch 3/10, Train Loss: nan, Val Loss: nan
# Epoch 4/10, Train Loss: nan, Val Loss: nan
# Epoch 5/10, Train Loss: nan, Val Loss: nan
# Epoch 6/10, Train Loss: nan, Val Loss: nan
# Epoch 7/10, Train Loss: nan, Val Loss: nan
# Epoch 8/10, Train Loss: nan, Val Loss: nan
# Epoch 9/10, Train Loss: nan, Val Loss: nan
# Epoch 10/10, Train Loss: nan, Val Loss: nan

# %%
# Plot training and validation losses
def plot_vae_losses(train_losses, val_losses, class_index):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'VAE Training and Validation Loss for Class {class_index}')
    plt.legend()
    plt.show()

# %%
# Example: Plot losses for class 0
plot_vae_losses(all_train_losses[0], all_val_losses[0], class_index=0)

# %% [markdown]
# ## Generative Adversarial Network (GAN)

# %% [markdown]
# ## Citation
#
# ```bibtex
# @techreport{krizhevsky2009learning,
#   title = {Learning Multiple Layers of Features from Tiny Images},
#   author = {Alex Krizhevsky},
#   institution = {University of Toronto},
#   year = {2009},
#   url = {https://www.cs.toronto.edu/~kriz/learning-features-2009-TR.pdf}
# }
